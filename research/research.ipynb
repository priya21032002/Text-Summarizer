# %%
1+1
# Out:
# 2

# %%
dict_info={"name":"Priya","lastname":"Lokhande"}

dict_info["name"]
# Out:
# 'Priya'

# %%
dict_info.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dict_info.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
from box import ConfigBox
dict_info=ConfigBox({"name":"Priya","lastname":"Lokhande"})
dict_info.name
# Out:
# 'Priya'

# %%
def multiplication(x:int,y:int)-> int:
    return x*y

# %%
multiplication(2,3)
# Out:
# 6

# %%
multiplication(2,"3")
# Out:
# '33'

# %%
2*"3"
# Out:
# '33'

# %%
from ensure import ensure_annotations

@ensure_annotations
def multiplication(x:int,y:int)-> int:
    return x*y

# %%
multiplication(2,"3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 multiplication(2,"3")
#
# File c:\Users\Priya\anaconda3\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function multiplication at 0x0000016F454E59E0> does not match annotation type <class 'int'>
